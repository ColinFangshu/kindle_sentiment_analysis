# %% [markdown]
# # Airpods tweets sentiment analysis
# ----Done by Colin Shu (https://github.com/ColinFangshu)
# <br> 8/6/2019

# %% [markdown]
# # Table of Contents
#
# 1.  [Introduction](#intro)
# 2.  [Import the raw tweets data](#GetData)
# <br>    2.1 [Clean the dataset](#import_and_drop_nan)
# <br>    2.2 [EDA](#EDA)

# %% [markdown]
# <a id='intro'><a/>
# ## 1. Introduction

# %% [markdown]
# <a id='GetData'><a/>
# ## 2. Import the raw tweets data

# %%
# import basic libraries
import pandas as pd
import numpy as np
np.random.seed(0)

# import libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# import tweepy library for accessing the twitter api
import tweepy

# import textblob library for basic sentiment analysis
import textblob

# %%
keys = []

with open('.secret') as f:
    for line in f:
        keys.append(line.strip())

# %%
# set the variables for accessing the twitter api
consumer_key = keys[0]
consumer_secret = keys[1]
access_token = keys[2]
access_token_secret = keys[3]  

# get the authentication of the api
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# search for tweets about airpods
public_tweets = api.search('airpods',
                           count=10000
                          )

# %%
for tweet in public_tweets:
    print(tweet.text)
# Out:
# My sister keep making fun of me for not having airpods but today she forgot a pair at home and the one she had on h… https://t.co/WNOd0LLkI3
# i lost one of my airpods :(
# 3+ weeks of working remotely from a small city in Kentucky and i finally realized what's so different
#
# cafes are ac… https://t.co/B1K0O8VsoQ
# @codyjmadrid do u even have airpods
# @PaulCharchian AirPods are my life.
# RT @eunsangft: keumdong said he named his airpods “bean sprouts” because it looked like bean sprouts,, what am i supposed to do with this i…
# can’t even put both airpods in bc of all these damn piercings 😂😂😂
# RT @EuToNoShawn1998: Fã: " Como você vai comemorar seu aniversário?"
#
# Shawn: " Eu vou estar em Nova York com uns 30 amigos que estão vindo…
# I don’t realize how much I love my AirPods till I leave them at home 😭
# allora ho paura per le mie airpods perché si bloccano che cacchio succede
# RT @BucciBanz: GIVEAWAY TIME.
# APPLE AIRPODS GEN 2 NEW.
#
# How to enter:
# 1. Must be following @buccibanz on twitter.
# 2. You must RT this tw…
# Airpods ve apple watch isteği çık aklımdan
# RT @Apple: AirPods with wireless charging. Free engraving exclusively online from Apple.
# RT @ConnorFeezy: Shoutout to the homeless dude that broke into my car and jacked my AirPods ... how the fuck are you going to listen to the…
# Los AirPods originales por 60€ está tirado de precio no?
# Tomorrow i'll just sit in any bus with airpods and say 'on to new york'.
# Let's see what the driver does.
# LOL
# .@ShawnMendes
# AirPods✅
# RT @holafanss: Es más fácil que la gente se quite los prejuicios que los Airpods.
# Sick I lost one of my AirPods I don’t be tryna hear nobody
# RT @fuccckinkidding: Mdzs au where everything is the same except instead of bein blind xxc is just always wearing AirPods https://t.co/B6OB…
# RT @sfkkfs_: Airpods ยังไม่มี ซื้อเคสมาเก็บไว้ก่อนได้ไหม น่ารักจริงจัง https://t.co/CgJqIIrKnT
# RT @HiMnm1210: 夏休みジャックポット初のプレゼント🎁任天堂switch3台とAirPods5台をプレゼントします！！
# RT @luisgp51: 📱IPHONE XS MAX &amp; AIRPODS GIVEAWAY
#
# To enter:
# - RETWEET
# - FOLLOW ME
# - NEW CHOOSE
# RT @BucciBanz: GIVEAWAY TIME.
# APPLE AIRPODS GEN 2 NEW.
#
# How to enter:
# 1. Must be following @buccibanz on twitter.
# 2. You must RT this tw…
# RT @UnboxTherapy: SONY is taking out every great pair of headphones... hard to make an argument for Airpods over these. So why would you? S…
# New Apple AirPods drop to their lowest ever price at Amazon
# https://t.co/Irw0OWuD84 https://t.co/5DqqtfydVd
# RT @luisgp51: 📱IPHONE XS MAX &amp; AIRPODS GIVEAWAY
#
# To enter:
# - RETWEET
# - FOLLOW ME
# - NEW CHOOSE
# RT @BucciBanz: GIVEAWAY TIME.
# APPLE AIRPODS GEN 2 NEW.
#
# How to enter:
# 1. Must be following @buccibanz on twitter.
# 2. You must RT this tw…
# alguem sabe de algum fone de ouvido tipo “airpods” que não custe o olho da cara?
# RT @luisgp51: 📱IPHONE XS MAX &amp; AIRPODS GIVEAWAY
#
# To enter:
# - RETWEET
# - FOLLOW ME
# - NEW CHOOSE
# Think ima sell my airpods once they get here🤔
# RT @sunnydelight: I hope you lose your AirPods
# RT @eunsangft: keumdong said he named his airpods “bean sprouts” because it looked like bean sprouts,, what am i supposed to do with this i…
# RT @luisgp51: 📱IPHONE XS MAX &amp; AIRPODS GIVEAWAY
#
# To enter:
# - RETWEET
# - FOLLOW ME
# - NEW CHOOSE
# RT @BucciBanz: GIVEAWAY TIME.
# APPLE AIRPODS GEN 2 NEW.
#
# How to enter:
# 1. Must be following @buccibanz on twitter.
# 2. You must RT this tw…
# RT @luisgp51: 📱IPHONE XS MAX &amp; AIRPODS GIVEAWAY
#
# To enter:
# - RETWEET
# - FOLLOW ME
# - NEW CHOOSE
# RT @luisgp51: 📱IPHONE XS MAX &amp; AIRPODS GIVEAWAY
#
# To enter:
# - RETWEET
# - FOLLOW ME
# - NEW CHOOSE
# Everyone has AirPods I’m ghetto with my EarPods :(
# RT @sankoiti_offici: ＊夏休み100万円分プレゼント＊
# AirPods を3台or BALENCIAGA のキャップを3個プレゼント🎁
#
# 応募方法はこのツイートをRTしてこのアカウントそして3人の個人のアカウントをフォローするだけです！
#
# 応募締め切りは8/…
# RT @BucciBanz: GIVEAWAY TIME.
# APPLE AIRPODS GEN 2 NEW.
#
# How to enter:
# 1. Must be following @buccibanz on twitter.
# 2. You must RT this tw…
# 📱IPHONE XS MAX &amp; AIRPODS GIVEAWAY
#
# To enter:
# - RETWEET
# - FOLLOW ME
# - NEW CHOOSE
# I think I'll get airpods instead #hordebeacon https://t.co/P89E1lVz0s
# RT @BucciBanz: GIVEAWAY TIME.
# APPLE AIRPODS GEN 2 NEW.
#
# How to enter:
# 1. Must be following @buccibanz on twitter.
# 2. You must RT this tw…

# %%
len(public_tweets)
# Out:
# 100
